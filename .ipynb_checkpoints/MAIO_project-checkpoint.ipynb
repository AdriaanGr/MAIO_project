# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import glob
from scipy.stats import linregress as lin

# %%
N = np.size(glob.glob("./JPL_mscn*.csv", recursive=True))
M = np.shape(np.genfromtxt('JPL_mscn017.csv', delimiter=',', skip_header=15))[0]

# %%
#glob.glob("./JPL_mscn*.csv", recursive=True)

# %%
file_n = glob.glob("./JPL_mscn*.csv", recursive=True)

data = np.empty((N, M, 2))
for i, fn in enumerate(file_n):
    file = np.genfromtxt(fn, delimiter=',', skip_header=15)
    #print(file.shape,i)
    data[i] = file

# %%
data_num = -1

xlist = 2002 + data[data_num-1][:,0]/365.25
ylist = data[data_num-1][:,1]

trend = lin(xlist,ylist)

f, ax = plt.subplots()
ax.plot(xlist,ylist,'.-',label = 'Data')
ax.plot(xlist,xlist * trend[0] + trend[1],label = 'Linear trend')
ax.set_xlabel('Year')
ax.set_ylabel('Mass [Gt]')
plt.legend()
ax.grid()
ax.text(0.58, 0.9, "Filename %s" % (file_n[data_num-1]), transform=f.transFigure)
plt.show()

# %%
xlist = 2002 + data[0][:,0]/365.25
ylist = np.sum(data, axis = 0)[:,1]

trend = lin(xlist,ylist)

plt.plot(xlist,ylist,'.-',label = 'Data')
plt.plot(xlist,xlist * trend[0] + trend[1],label = 'Linear trend')
plt.title('Total Greenland mass change')
plt.xlabel('Year')
plt.ylabel('Mass [Gt]')
plt.grid()
plt.show()

# %%
F = data[:,:,1].T
FT = np.copy(F.T)
for i in range(FT.shape[0]):
    FT[i] -= FT[i].mean()
F = np.copy(FT.T)
C = np.dot(FT, F)
evals, evecs = np.linalg.eig(C)
PCA = np.dot(F, evecs[:])

# %%
PCA_num = 3

plt.plot(xlist, PCA[:,PCA_num-1])
plt.xlabel('Year')
plt.ylabel('Mass [Gt]')
plt.title('PC' + str(PCA_num))
plt.grid()
plt.show()

# %%
pca_max = 10
bars = evals / evals.sum()*100
plt.bar(x=range(1,pca_max+1), height=bars[:pca_max])
plt.xlabel('Principle component')
plt.ylabel('Percentage of Explained Variance')
plt.grid()
plt.show()

# %%
2/(np.cos(64/360*2*np.pi)*4557*3/360*2*np.pi)*(360/(2*np.pi))
# Out:
# 1.0955520495110391

# %%
R_earth = 6371*10**3
A_earth = 4*np.pi*R_earth**2
N_c = 4551
teta = np.arange(-87,90,3)
teta = 2*np.pi/360*teta

# %%
def dellam(teta):
    return(4*np.pi/(np.cos(teta)*N_c* 3/360*2*np.pi))

# %%
lamda.shape
# Out:
# (59, 119)

# %%
lamda = np.zeros((teta.size, int(2.0 * np.pi // dellam(0))))
for i in range(teta.size):
    for j in range(lamda.shape[1]):
        lamda[i,j] = (j) * dellam(teta[i])
        if lamda[i,j] >= 2*np.pi:
            lamda[i,j] = np.nan

# %%
lon = np.zeros(lamda.shape)
for i in range(lamda.shape[0]):
    lon[i,:] = 360/(2*np.pi)*lamda[i,:]*2*np.pi/np.nanmax(lamda[i])

lat = 360/(2*np.pi)*teta+1.5
#lon = 360/(2*np.pi)*lamda

# %%
#nans = np.logical_not(np.isnan(lon[0,:]))
#print(nans)

#np.interp(lon[29], lon[0][nans], np.arange(lon[0,:].size)[nans])

# %%
#fit = np.zeros(lon[29].size)
#testdata = np.arange(lon[0,:].size)
#j = 0
#for i in range(fit.size):
#    if lon[29,i] > lon[0,j+1] and not np.isnan(lon[0,j+1]):
#        j += 1
#    fit[i] = testdata[j]
#fit[-1] = fit[0]
#print(fit)

# %%
sdata = data[:,:,1]

# %%
year = 2013
time = np.argmin(np.abs(xlist - year))
fit = np.zeros((lat.size, lon[0].size))

for k in range(lon.shape[0]):
    sz = np.sum(np.logical_not(np.isnan(lon[k])))
    al = np.zeros(lon[k].size)
    if k == 1:
        al[sz-3] = sdata[0][time]
        al[sz-2] = sdata[1][time]
    if k == 2:
        al[sz-5] = sdata[2][time]
        al[sz-4] = sdata[3][time]
        al[sz-3] = sdata[4][time]
        al[sz-2] = sdata[5][time]
    if k == 3:
        al[sz-6] = sdata[6][time]
        al[sz-5] = sdata[7][time]
        al[sz-4] = sdata[8][time]
        al[sz-3] = sdata[9][time]
    if k == 4:
        al[sz-7] = sdata[10][time]
        al[sz-6] = sdata[11][time]
        al[sz-5] = sdata[12][time]
        al[sz-4] = sdata[13][time]
        al[sz-3] = sdata[14][time]
    if k == 5:
        al[sz-7] = sdata[15][time]
        al[sz-6] = sdata[16][time]
        al[sz-5] = sdata[17][time]
        al[sz-4] = sdata[18][time]
    if k == 6:
        al[sz-8] = sdata[19][time]
        al[sz-7] = sdata[20][time]
        al[sz-6] = sdata[21][time]
        al[sz-5] = sdata[22][time]
        al[sz-4] = sdata[23][time]
    if k == 7:
        al[sz-9] = sdata[24][time]
        al[sz-8] = sdata[25][time]
        al[sz-7] = sdata[26][time]
        al[sz-6] = sdata[27][time]
    if k == 8:
        al[sz-9] = sdata[28][time]
        al[sz-8] = sdata[29][time]
    if k == 9:
        al[sz-9] = sdata[30][time]
    #fit = np.zeros(lon[29].size)
    j = 0
    for i in range(fit.shape[1]):
        if lon[29,i] > lon[k,j+1] and not np.isnan(lon[k,j+1]):
            j += 1
        fit[k,i] = al[j]
    fit[k,-1] = fit[k,0]

# %%
fig = plt.figure(figsize=(18,9))

ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

#ax.stock_img()
ax.coastlines()
plt.axis([-80,0,55,85])
#plt.xticks(np.arange(-80,101,20),np.arange(100,281,20), fontsize=15)  
#plt.yticks(np.arange(-30,31,10), fontsize=15) 
CS = plt.pcolormesh(lon[29],-lat+3, fit, cmap=plt.cm.RdBu_r, vmin = -np.max(np.abs(fit)), vmax = np.max(np.abs(fit)))#, levels = np.arange(-130,131,20))
#for c in CS.collections:
#    c.set_edgecolor("face")
#plt.xlabel('longitude [$\degree$E]', fontsize=15)
#plt.ylabel('latitude [$\degree$N]', fontsize=15)
#plt.title('Sea surface height anomaly December 2018', fontsize=15)
plt.title("Year %.0f" % xlist[time])
plt.grid(True)
plt.colorbar(fraction=0.02, pad=0.04)

# December 2018
plt.show()

# %%
eof_i = 2
fit = np.zeros((lat.size, lon[0].size))

for k in range(lon.shape[0]):
    sz = np.sum(np.logical_not(np.isnan(lon[k])))
    al = np.zeros(lon[k].size)
    if k == 1:
        al[sz-3] = evecs[0,eof_i-1]
        al[sz-2] = evecs[1,eof_i-1]
    if k == 2:
        al[sz-5] = evecs[2,eof_i-1]
        al[sz-4] = evecs[3,eof_i-1]
        al[sz-3] = evecs[4,eof_i-1]
        al[sz-2] = evecs[5,eof_i-1]
    if k == 3:
        al[sz-6] = evecs[6,eof_i-1]
        al[sz-5] = evecs[7,eof_i-1]
        al[sz-4] = evecs[8,eof_i-1]
        al[sz-3] = evecs[9,eof_i-1]
    if k == 4:
        al[sz-7] = evecs[10,eof_i-1]
        al[sz-6] = evecs[11,eof_i-1]
        al[sz-5] = evecs[12,eof_i-1]
        al[sz-4] = evecs[13,eof_i-1]
        al[sz-3] = evecs[14,eof_i-1]
    if k == 5:
        al[sz-7] = evecs[15,eof_i-1]
        al[sz-6] = evecs[16,eof_i-1]
        al[sz-5] = evecs[17,eof_i-1]
        al[sz-4] = evecs[18,eof_i-1]
    if k == 6:
        al[sz-8] = evecs[19,eof_i-1]
        al[sz-7] = evecs[20,eof_i-1]
        al[sz-6] = evecs[21,eof_i-1]
        al[sz-5] = evecs[22,eof_i-1]
        al[sz-4] = evecs[23,eof_i-1]
    if k == 7:
        al[sz-9] = evecs[24,eof_i-1]
        al[sz-8] = evecs[25,eof_i-1]
        al[sz-7] = evecs[26,eof_i-1]
        al[sz-6] = evecs[27,eof_i-1]
    if k == 8:
        al[sz-9] = evecs[28,eof_i-1]
        al[sz-8] = evecs[29,eof_i-1]
    if k == 9:
        al[sz-9] = evecs[30,eof_i-1]
    #fit = np.zeros(lon[29].size)
    j = 0
    for i in range(fit[0].size):
        if lon[29,i] > lon[k,j+1] and not np.isnan(lon[k,j+1]):
            j += 1
        fit[k,i] = al[j]
    fit[k,-1] = fit[k,0]

# %%
fig = plt.figure(figsize=(18,9))

ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

#ax.stock_img()
ax.coastlines()
plt.axis([-80,0,55,85])
#plt.xticks(np.arange(-80,101,20),np.arange(100,281,20), fontsize=15)  
#plt.yticks(np.arange(-30,31,10), fontsize=15) 
CS = plt.pcolormesh(lon[29],-lat+3, fit, cmap=plt.cm.RdBu_r, vmin = -np.max(np.abs(fit)), vmax = np.max(np.abs(fit)))#, levels = np.arange(-130,131,20))
#for c in CS.collections:
#    c.set_edgecolor("face")
#plt.xlabel('longitude [$\degree$E]', fontsize=15)
#plt.ylabel('latitude [$\degree$N]', fontsize=15)
#plt.title('Sea surface height anomaly December 2018', fontsize=15)
plt.title('EOF' + str(eof_i))
plt.grid(True)
plt.colorbar(fraction=0.02, pad=0.04)

# December 2018
plt.show()
